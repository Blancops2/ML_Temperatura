# %%
import pandas as pd

# %% [markdown]
# libreria de pandas

# %%
from sklearn.linear_model import LinearRegression

# %%
datos=pd.read_csv("datos.csv")

# %% [markdown]
# variable con nuestros datos

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Celsius     5 non-null      int64
#  1   Fahrenheit  5 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 212.0 bytes

# %%
datos.head()
# Out:
#    Celsius  Fahrenheit
# 0        0        32.0
# 1       10        50.0
# 2      -40       -40.0
# 3        7        44.6
# 4       20        68.0

# %%
import seaborn as sb
sb.scatterplot(x='Celsius',y='Fahrenheit',data=datos, hue='Fahrenheit')
# Out:
# <Axes: xlabel='Celsius', ylabel='Fahrenheit'>

# %% [markdown]
# para graficas

# %%
#aracteristicas es el eje x y las etiquetas es el eje y
X=datos["Celsius"]
Y=datos["Fahrenheit"]

# %%
X
# Out:
# 0     0
# 1    10
# 2   -40
# 3     7
# 4    20
# Name: Celsius, dtype: int64

# %%
Y
# Out:
# 0    32.0
# 1    50.0
# 2   -40.0
# 3    44.6
# 4    68.0
# Name: Fahrenheit, dtype: float64

# %%
X.values
# Out:
# array([  0,  10, -40,   7,  20])

# %%
Y.values
# Out:
# array([ 32. ,  50. , -40. ,  44.6,  68. ])

# %%
X_Procesada=X.values.reshape(-1,1)
Y_Procesada=Y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
modelo=LinearRegression()

# %%
modelo.fit(X_Procesada,Y_Procesada)
# Out:
# LinearRegression()

# %%
modelo.predict([[0]])
# Out:
# array([[32.]])

# %%
modelo.predict([[23]])
# Out:
# array([[73.4]])

# %%
modelo.score(X_Procesada,Y_Procesada)
# Out:
# 1.0

# %% [markdown]
# precision
